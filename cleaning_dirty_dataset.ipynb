# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("dirty_dataset.csv")
data.head()
# Out:
#     ID   Name   Age     City   Salary
# 0  353  Sneha  23.0      NaN  35000.0
# 1  690  Sneha  22.0  Kolkata  25000.0
# 2  486  Sneha  25.0  Kolkata  40000.0
# 3  389   Amit  25.0   Mumbai  25000.0
# 4   32  Rohan  23.0   Mumbai  40000.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1050 non-null   int64
#  1   Name    905 non-null    object
#  2   Age     901 non-null    float64
#  3   City    880 non-null    object
#  4   Salary  872 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 41.1+ KB

# %%
data.shape
# Out:
# (1050, 5)

# %%
data.describe()
# Out:
#                 ID         Age        Salary
# count  1050.000000  901.000000    872.000000
# mean    502.380952   22.473918  35149.082569
# std     288.838378    1.736099   7089.765530
# min       1.000000   20.000000  25000.000000
# 25%     253.250000   21.000000  30000.000000
# 50%     503.500000   22.000000  35000.000000
# 75%     751.750000   24.000000  40000.000000
# max    1000.000000   25.000000  45000.000000

# %%
data.isnull().sum()
# Out:
# ID          0
# Name      145
# Age       149
# City      170
# Salary    178
# dtype: int64

# %%
data['Age']=data['Age'].fillna(data['Age'].median())

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Salary']=data['Salary'].fillna(data['Salary'].median())
data.head()
# Out:
#     ID   Name   Age     City   Salary
# 0  353  Sneha  23.0      NaN  35000.0
# 1  690  Sneha  22.0  Kolkata  25000.0
# 2  486  Sneha  25.0  Kolkata  40000.0
# 3  389   Amit  25.0   Mumbai  25000.0
# 4   32  Rohan  23.0   Mumbai  40000.0

# %%
data['City']=data['City'].fillna(data['City'].mode()[0])
data['City'].unique()
# Out:
# array(['Chennai', 'Kolkata', 'Mumbai', 'Bangalore', 'Delhi'], dtype=object)

# %%
data['Name']=data['Name'].fillna(data['Name'].mode()[0])
data.isnull().sum()
# Out:
# ID        0
# Name      0
# Age       0
# City      0
# Salary    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(50)

# %%
df=data.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#     ID   Name   Age     City   Salary
# 0  353  Sneha  23.0  Chennai  35000.0
# 1  690  Sneha  22.0  Kolkata  25000.0
# 2  486  Sneha  25.0  Kolkata  40000.0
# 3  389   Amit  25.0   Mumbai  25000.0
# 4   32  Rohan  23.0   Mumbai  40000.0

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Age       0
# City      0
# Salary    0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#     ID   Name   Age     City   Salary
# 0  353  Sneha  23.0  Chennai  35000.0
# 1  690  Sneha  22.0  Kolkata  25000.0
# 2  486  Sneha  25.0  Kolkata  40000.0
# 3  389   Amit  25.0   Mumbai  25000.0
# 4   32  Rohan  23.0   Mumbai  40000.0

# %%
df=df.drop(columns='ID')
df=df.drop(columns='Name')

# %%
df.head()
# Out:
#     Age     City   Salary
# 0  23.0  Chennai  35000.0
# 1  22.0  Kolkata  25000.0
# 2  25.0  Kolkata  40000.0
# 3  25.0   Mumbai  25000.0
# 4  23.0   Mumbai  40000.0

# %%
df=pd.get_dummies(df, columns=['City'])

# %%
df.head()
# Out:
#     Age   Salary  City_Bangalore  City_Chennai  City_Delhi  City_Kolkata  \
# 0  23.0  35000.0           False          True       False         False
# 1  22.0  25000.0           False         False       False          True
# 2  25.0  40000.0           False         False       False          True
# 3  25.0  25000.0           False         False       False         False
# 4  23.0  40000.0           False         False       False         False
#
#    City_Mumbai
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True

# %%
x=df.drop(columns='Salary')
y=df['Salary']

# %%
x.head()
# Out:
#     Age  City_Bangalore  City_Chennai  City_Delhi  City_Kolkata  City_Mumbai
# 0  23.0           False          True       False         False        False
# 1  22.0           False         False       False          True        False
# 2  25.0           False         False       False          True        False
# 3  25.0           False         False       False         False         True
# 4  23.0           False         False       False         False         True

# %%
y.head()
# Out:
# 0    35000.0
# 1    25000.0
# 2    40000.0
# 3    25000.0
# 4    40000.0
# Name: Salary, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state